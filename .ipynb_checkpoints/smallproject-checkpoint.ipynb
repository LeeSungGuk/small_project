# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pylab as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.cross_validation import StratifiedKFold
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from sklearn.linear_model import LinearRegression

# %%
read_file = pd.read_excel('./resource/teamproject_data1.xlsx', sheetname=0)

df_scale = scale(read_file)
df_data = pd.DataFrame(data = df_scale, columns = read_file.columns)
#print(df_data['accident'], df_scale[:,-1:])

# %%
# 상관관계 구하기
df_data.corr()
# Out:
#                       date  accident  taxi_driver     speed  temperature  \
# date              1.000000  0.252083    -0.922514 -0.555033     0.054314
# accident          0.252083  1.000000    -0.525679 -0.513479     0.584964
# taxi_driver      -0.922514 -0.525679     1.000000  0.691914    -0.274890
# speed            -0.555033 -0.513479     0.691914  1.000000    -0.288751
# temperature       0.054314  0.584964    -0.274890 -0.288751     1.000000
# rainfall         -0.175927  0.135401     0.083854 -0.146436     0.496143
# humidity          0.018305  0.389020    -0.247492 -0.435259     0.631274
# dew_point         0.043498  0.575799    -0.279732 -0.335245     0.986712
# sun               0.121565  0.273114    -0.113295  0.075180     0.160639
# wind_speed       -0.132541 -0.116434     0.250143  0.285546    -0.119645
# total_population -0.880127 -0.434463     0.920305  0.706207    -0.114039
# over_65           0.961769  0.402047    -0.962764 -0.712052     0.113730
# total_vehicle     0.933223  0.416703    -0.946845 -0.657475     0.101010
# sedan             0.945166  0.418520    -0.957415 -0.676027     0.104773
# van              -0.957561 -0.408534     0.964608  0.680608    -0.088760
# truck            -0.817450 -0.361412     0.822594  0.735086    -0.179415
# special_car       0.950240  0.413490    -0.957262 -0.683796     0.108669
# bicycle           0.693936  0.502958    -0.796580 -0.753067     0.294405
#
#                   rainfall  humidity  dew_point       sun  wind_speed  \
# date             -0.175927  0.018305   0.043498  0.121565   -0.132541
# accident          0.135401  0.389020   0.575799  0.273114   -0.116434
# taxi_driver       0.083854 -0.247492  -0.279732 -0.113295    0.250143
# speed            -0.146436 -0.435259  -0.335245  0.075180    0.285546
# temperature       0.496143  0.631274   0.986712  0.160639   -0.119645
# rainfall          1.000000  0.656162   0.559797 -0.474195    0.307348
# humidity          0.656162  1.000000   0.747472 -0.542955   -0.166514
# dew_point         0.559797  0.747472   1.000000  0.025246   -0.144863
# sun              -0.474195 -0.542955   0.025246  1.000000    0.039092
# wind_speed        0.307348 -0.166514  -0.144863  0.039092    1.000000
# total_population  0.132068 -0.138702  -0.120977 -0.049950    0.328294
# over_65          -0.136903  0.132013   0.118904  0.084629   -0.245394
# total_vehicle    -0.092548  0.124866   0.105906  0.054353   -0.227444
# sedan            -0.105711  0.126239   0.109540  0.064552   -0.236360
# van               0.151077 -0.107948  -0.092327 -0.086162    0.247877
# truck             0.118187 -0.164120  -0.183822 -0.123419    0.256592
# special_car      -0.122352  0.111002   0.109722  0.083879   -0.232016
# bicycle          -0.062116  0.340758   0.319192  0.077854   -0.360150
#
#                   total_population   over_65  total_vehicle     sedan  \
# date                     -0.880127  0.961769       0.933223  0.945166
# accident                 -0.434463  0.402047       0.416703  0.418520
# taxi_driver               0.920305 -0.962764      -0.946845 -0.957415
# speed                     0.706207 -0.712052      -0.657475 -0.676027
# temperature              -0.114039  0.113730       0.101010  0.104773
# rainfall                  0.132068 -0.136903      -0.092548 -0.105711
# humidity                 -0.138702  0.132013       0.124866  0.126239
# dew_point                -0.120977  0.118904       0.105906  0.109540
# sun                      -0.049950  0.084629       0.054353  0.064552
# wind_speed                0.328294 -0.245394      -0.227444 -0.236360
# total_population          1.000000 -0.941091      -0.941119 -0.948599
# over_65                  -0.941091  1.000000       0.962816  0.978668
# total_vehicle            -0.941119  0.962816       1.000000  0.997702
# sedan                    -0.948599  0.978668       0.997702  1.000000
# van                       0.964130 -0.992709      -0.979590 -0.989852
# truck                     0.755645 -0.889572      -0.753192 -0.793442
# special_car              -0.973530  0.982956       0.983798  0.990477
# bicycle                  -0.664190  0.801192       0.674774  0.711443
#
#                        van     truck  special_car   bicycle
# date             -0.957561 -0.817450     0.950240  0.693936
# accident         -0.408534 -0.361412     0.413490  0.502958
# taxi_driver       0.964608  0.822594    -0.957262 -0.796580
# speed             0.680608  0.735086    -0.683796 -0.753067
# temperature      -0.088760 -0.179415     0.108669  0.294405
# rainfall          0.151077  0.118187    -0.122352 -0.062116
# humidity         -0.107948 -0.164120     0.111002  0.340758
# dew_point        -0.092327 -0.183822     0.109722  0.319192
# sun              -0.086162 -0.123419     0.083879  0.077854
# wind_speed        0.247877  0.256592    -0.232016 -0.360150
# total_population  0.964130  0.755645    -0.973530 -0.664190
# over_65          -0.992709 -0.889572     0.982956  0.801192
# total_vehicle    -0.979590 -0.753192     0.983798  0.674774
# sedan            -0.989852 -0.793442     0.990477  0.711443
# van               1.000000  0.834793    -0.995879 -0.742787
# truck             0.834793  1.000000    -0.802673 -0.916389
# special_car      -0.995879 -0.802673     1.000000  0.699516
# bicycle          -0.742787 -0.916389     0.699516  1.000000

# %%
df_cons = sm.add_constant(df_data.ix[:,:-1])
df_y    = pd.DataFrame(data = df_scale[:,-1:], columns = ['accident/day'])

# %%
model = sm.OLS(df_y, df_cons)
result_model = model.fit()
print(result_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           accident/day   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     58.51
# Date:                Wed, 26 Oct 2016   Prob (F-statistic):           9.08e-13
# Time:                        21:27:46   Log-Likelihood:                 19.432
# No. Observations:                  36   AIC:                            -4.863
# Df Residuals:                      19   BIC:                             22.06
# Df Model:                          16
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const             4.556e-14      0.032   1.41e-12      1.000        -0.068     0.068
# date                -0.3895      0.311     -1.252      0.226        -1.041     0.262
# accident             0.0704      0.079      0.896      0.382        -0.094     0.235
# taxi_driver         -0.5148      0.312     -1.649      0.116        -1.168     0.139
# speed               -0.0730      0.114     -0.641      0.529        -0.311     0.165
# temperature          2.1608      1.626      1.329      0.200        -1.243     5.564
# rainfall             0.1155      0.076      1.512      0.147        -0.044     0.275
# humidity             0.5487      0.392      1.399      0.178        -0.272     1.369
# dew_point           -2.5933      1.836     -1.413      0.174        -6.436     1.249
# sun                  0.1146      0.089      1.285      0.214        -0.072     0.301
# wind_speed          -0.1173      0.061     -1.911      0.071        -0.246     0.011
# total_population    -0.4760      0.303     -1.569      0.133        -1.111     0.159
# over_65              4.8857      1.440      3.394      0.003         1.872     7.899
# total_vehicle        0.0280      0.259      0.108      0.915        -0.513     0.569
# sedan               -0.0897      0.249     -0.361      0.722        -0.610     0.431
# van                  0.8515      1.777      0.479      0.637        -2.867     4.570
# truck                0.3370      0.272      1.238      0.231        -0.233     0.907
# special_car         -3.6220      1.027     -3.527      0.002        -5.771    -1.473
# ==============================================================================
# Omnibus:                        3.371   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.847
# Skew:                           0.685   Prob(JB):                        0.241
# Kurtosis:                       2.864   Cond. No.                     2.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.33e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
influence = result_model.get_influence()
hat = influence.hat_matrix_diag
plt.stem(hat)
plt.axis([ -2, len(df_y)+2, 0, 2 ])
plt.show()
print("hat.sum() =", hat.sum())
# Out:
# ('hat.sum() =', 17.0)

# %%
#레버리지
sm.graphics.plot_leverage_resid2(result_model)
plt.show()

# %%
#아웃라이어
plt.figure(figsize=(10, 2))
plt.stem(result_model.outlier_test().ix[:, -1])
plt.show()

# %%
#df_PCA = PCA(5).fit_transform(df_data.ix[:, :-1])


pca = PCA(n_components=5)
pca_data = pca.fit(df_data.ix[:, :-1])

pca_ratio_idx = pca_data.explained_variance_ratio_

total_ratio = 0
for i in pca_ratio_idx :
    total_ratio += i

print(total_ratio)

#transform
pca_data_t= pca_data.transform(df_data.ix[:, :-1])
print(pca_data_t)
# Out:
# 0.940255487698
# [[-5.2660799   1.53553633 -1.03853819  0.52396045  0.00858347]
#  [-5.31200794  1.78039297 -1.2304737  -0.18610865 -0.65316663]
#  [-4.84081477  1.56449876  1.35031622 -0.8709455  -0.13596395]
#  [-4.53372156  0.49330044  0.57774944 -1.8529641  -0.1466755 ]
#  [-3.73087924 -0.90873902  1.47252706 -0.69003373 -0.11578085]
#  [-2.90811027 -1.36002084  1.7079292   1.71486491 -0.29860566]
#  [-2.88118297 -5.49511996 -3.19005565 -2.41198484  0.24707412]
#  [-2.4891793  -2.57533011  0.69036973  0.09834097 -0.25610017]
#  [-2.19390436 -1.65297381  0.20995396  1.72794477 -0.13058812]
#  [-1.91100087 -0.4406654   1.56053635  0.99517849  1.1437318 ]
#  [-2.05654501  0.22721052 -0.2079127   0.59776418  1.71973448]
#  [-2.44646255  1.16724354 -0.79632903  1.43436011  0.61753646]
#  [-2.53250145  2.63349049 -1.0010262   1.00291685 -1.03688613]
#  [-2.23865237  2.30571007 -1.46151782  0.27395611 -1.31562708]
#  [-1.30803129  0.76330907  0.17839219 -0.5719849   0.23746157]
#  [-0.80533732  0.13684869  0.35361462 -0.0840983  -0.04215823]
#  [-0.24328351 -0.32120413  2.24361042 -1.60131311  0.62060907]
#  [ 0.18167299 -2.12783166  0.05055241  0.54435329 -0.07114229]
#  [ 0.44892668 -2.99457109 -0.20582394 -0.30498894  0.09474831]
#  [ 0.87498682 -2.88891019 -0.80044823  1.03449256 -0.29031883]
#  [ 1.19282335 -1.4191978   0.52837806  1.67086784 -0.48269962]
#  [ 1.31803934 -0.33093281  1.02427038  0.74987205  0.47688503]
#  [ 1.34160005  0.3101124  -0.1155288   0.6476681   1.01357878]
#  [ 1.21667682  1.89311703 -0.69970933 -0.16342596  1.75095312]
#  [ 1.26351487  2.50999591 -1.22922286  0.13388414 -0.46319602]
#  [ 1.57545566  2.21177787 -1.93645924 -0.48221071 -0.48876077]
#  [ 2.01811743  2.69790498  0.99172983 -1.75222935  0.19487727]
#  [ 2.60779509  0.87877658  0.03710955 -1.60375583  0.09782288]
#  [ 3.0131942   0.91598106  1.93629314 -1.56929276 -0.17779616]
#  [ 3.32287854 -0.10565851  1.07176633 -0.20558557 -1.42505649]
#  [ 3.78751331 -2.03083601 -0.67526104 -0.90247518 -0.77947471]
#  [ 4.19994303 -1.24969854  0.27660463  0.48355472 -1.12638285]
#  [ 4.56746308  0.28278621  1.5458046   0.4562293  -0.29943747]
#  [ 4.73608186  0.27287986  0.62646328  0.40758659  0.11114609]
#  [ 4.98204808 -0.53609499 -2.50137384 -0.01087488  0.90691601]
#  [ 5.0489635   1.85691209 -1.34429084  0.76647686  0.49415906]]

# %%
#df_data1 = pd.DataFrame(data = df_PCA, columns = read_file.columns[0:14])
df_data1 = pd.DataFrame(data = pca_data_t, columns = ['x1', 'x2', 'x3', 'x4', 'x5'])
df_cons = sm.add_constant(df_data1) # acciendt 값은 포함안됨
df_y    = pd.DataFrame(data = df_scale[:,-1:], columns = ['accident/day'])

# %%
#model_diabetes2 = sm.OLS(df_diabetes.ix[:, -1], df_diabetes.ix[:, :-1])

model = sm.OLS(df_y, df_cons)
result_model = model.fit()
print(result_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           accident/day   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     15.40
# Date:                Wed, 26 Oct 2016   Prob (F-statistic):           1.62e-07
# Time:                        21:28:05   Log-Likelihood:                -28.194
# No. Observations:                  36   AIC:                             68.39
# Df Residuals:                      30   BIC:                             77.89
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       6.024e-15      0.097   6.23e-14      1.000        -0.197     0.197
# x1             0.2641      0.032      8.364      0.000         0.200     0.329
# x2            -0.0726      0.052     -1.384      0.177        -0.180     0.035
# x3             0.0490      0.077      0.637      0.529        -0.108     0.206
# x4             0.1563      0.092      1.699      0.100        -0.032     0.344
# x5             0.1807      0.134      1.353      0.186        -0.092     0.453
# ==============================================================================
# Omnibus:                        0.122   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.941   Jarque-Bera (JB):                0.248
# Skew:                           0.123   Prob(JB):                        0.884
# Kurtosis:                       2.677   Cond. No.                         4.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(df_y.values.T)
# Out:
# [[-2.01278764 -2.06072347 -1.85943953 -1.63604927 -1.36821365 -1.13272308
#   -0.96960165 -0.76761962 -0.60007692 -0.43160343 -0.36295747 -0.47186022
#   -0.56005283 -0.5253808  -0.30036165  0.01308281  0.32908695  0.62065779
#    0.93805812  1.17587567  1.48257188  1.71131421  1.72271642  0.88988959
#    0.49662965  0.35445106  0.33862758  0.41471989  0.49756044  0.4510208
#    0.60180923  0.77679827  0.90943624  0.70117136  0.49732774  0.13664555]]

# %%
print(df_cons.values)
# Out:
# [[ 1.         -5.2660799   1.53553633 -1.03853819  0.52396045  0.00858347]
#  [ 1.         -5.31200794  1.78039297 -1.2304737  -0.18610865 -0.65316663]
#  [ 1.         -4.84081477  1.56449876  1.35031622 -0.8709455  -0.13596395]
#  [ 1.         -4.53372156  0.49330044  0.57774944 -1.8529641  -0.1466755 ]
#  [ 1.         -3.73087924 -0.90873902  1.47252706 -0.69003373 -0.11578085]
#  [ 1.         -2.90811027 -1.36002084  1.7079292   1.71486491 -0.29860566]
#  [ 1.         -2.88118297 -5.49511996 -3.19005565 -2.41198484  0.24707412]
#  [ 1.         -2.4891793  -2.57533011  0.69036973  0.09834097 -0.25610017]
#  [ 1.         -2.19390436 -1.65297381  0.20995396  1.72794477 -0.13058812]
#  [ 1.         -1.91100087 -0.4406654   1.56053635  0.99517849  1.1437318 ]
#  [ 1.         -2.05654501  0.22721052 -0.2079127   0.59776418  1.71973448]
#  [ 1.         -2.44646255  1.16724354 -0.79632903  1.43436011  0.61753646]
#  [ 1.         -2.53250145  2.63349049 -1.0010262   1.00291685 -1.03688613]
#  [ 1.         -2.23865237  2.30571007 -1.46151782  0.27395611 -1.31562708]
#  [ 1.         -1.30803129  0.76330907  0.17839219 -0.5719849   0.23746157]
#  [ 1.         -0.80533732  0.13684869  0.35361462 -0.0840983  -0.04215823]
#  [ 1.         -0.24328351 -0.32120413  2.24361042 -1.60131311  0.62060907]
#  [ 1.          0.18167299 -2.12783166  0.05055241  0.54435329 -0.07114229]
#  [ 1.          0.44892668 -2.99457109 -0.20582394 -0.30498894  0.09474831]
#  [ 1.          0.87498682 -2.88891019 -0.80044823  1.03449256 -0.29031883]
#  [ 1.          1.19282335 -1.4191978   0.52837806  1.67086784 -0.48269962]
#  [ 1.          1.31803934 -0.33093281  1.02427038  0.74987205  0.47688503]
#  [ 1.          1.34160005  0.3101124  -0.1155288   0.6476681   1.01357878]
#  [ 1.          1.21667682  1.89311703 -0.69970933 -0.16342596  1.75095312]
#  [ 1.          1.26351487  2.50999591 -1.22922286  0.13388414 -0.46319602]
#  [ 1.          1.57545566  2.21177787 -1.93645924 -0.48221071 -0.48876077]
#  [ 1.          2.01811743  2.69790498  0.99172983 -1.75222935  0.19487727]
#  [ 1.          2.60779509  0.87877658  0.03710955 -1.60375583  0.09782288]
#  [ 1.          3.0131942   0.91598106  1.93629314 -1.56929276 -0.17779616]
#  [ 1.          3.32287854 -0.10565851  1.07176633 -0.20558557 -1.42505649]
#  [ 1.          3.78751331 -2.03083601 -0.67526104 -0.90247518 -0.77947471]
#  [ 1.          4.19994303 -1.24969854  0.27660463  0.48355472 -1.12638285]
#  [ 1.          4.56746308  0.28278621  1.5458046   0.4562293  -0.29943747]
#  [ 1.          4.73608186  0.27287986  0.62646328  0.40758659  0.11114609]
#  [ 1.          4.98204808 -0.53609499 -2.50137384 -0.01087488  0.90691601]
#  [ 1.          5.0489635   1.85691209 -1.34429084  0.76647686  0.49415906]]

# %%
cv = StratifiedKFold(df_y['accident/day'], n_folds=5, random_state=0)



#cv = StratifiedKFold(df_y.values.T, n_folds=5, random_state=0)
for train_index, test_index in cv:
    print("test X:\n", df_cons.ix[test_index])
    print("." * 80 )        
    print("test y:", df_y['accident/day'][test_index])
    print("=" * 80 )
# Out:
# ('test X:\n',     const        x1        x2        x3        x4        x5
# 0       1 -5.266080  1.535536 -1.038538  0.523960  0.008583
# 1       1 -5.312008  1.780393 -1.230474 -0.186109 -0.653167
# 2       1 -4.840815  1.564499  1.350316 -0.870946 -0.135964
# 3       1 -4.533722  0.493300  0.577749 -1.852964 -0.146675
# 4       1 -3.730879 -0.908739  1.472527 -0.690034 -0.115781
# 5       1 -2.908110 -1.360021  1.707929  1.714865 -0.298606
# 6       1 -2.881183 -5.495120 -3.190056 -2.411985  0.247074
# 7       1 -2.489179 -2.575330  0.690370  0.098341 -0.256100
# 8       1 -2.193904 -1.652974  0.209954  1.727945 -0.130588
# 9       1 -1.911001 -0.440665  1.560536  0.995178  1.143732
# 10      1 -2.056545  0.227211 -0.207913  0.597764  1.719734
# 11      1 -2.446463  1.167244 -0.796329  1.434360  0.617536
# 12      1 -2.532501  2.633490 -1.001026  1.002917 -1.036886
# 13      1 -2.238652  2.305710 -1.461518  0.273956 -1.315627
# 14      1 -1.308031  0.763309  0.178392 -0.571985  0.237462
# 15      1 -0.805337  0.136849  0.353615 -0.084098 -0.042158
# 16      1 -0.243284 -0.321204  2.243610 -1.601313  0.620609
# 17      1  0.181673 -2.127832  0.050552  0.544353 -0.071142
# 18      1  0.448927 -2.994571 -0.205824 -0.304989  0.094748
# 19      1  0.874987 -2.888910 -0.800448  1.034493 -0.290319
# 20      1  1.192823 -1.419198  0.528378  1.670868 -0.482700
# 21      1  1.318039 -0.330933  1.024270  0.749872  0.476885
# 22      1  1.341600  0.310112 -0.115529  0.647668  1.013579
# 23      1  1.216677  1.893117 -0.699709 -0.163426  1.750953
# 24      1  1.263515  2.509996 -1.229223  0.133884 -0.463196
# 25      1  1.575456  2.211778 -1.936459 -0.482211 -0.488761
# 26      1  2.018117  2.697905  0.991730 -1.752229  0.194877
# 27      1  2.607795  0.878777  0.037110 -1.603756  0.097823
# 28      1  3.013194  0.915981  1.936293 -1.569293 -0.177796
# 29      1  3.322879 -0.105659  1.071766 -0.205586 -1.425056
# 30      1  3.787513 -2.030836 -0.675261 -0.902475 -0.779475
# 31      1  4.199943 -1.249699  0.276605  0.483555 -1.126383
# 32      1  4.567463  0.282786  1.545805  0.456229 -0.299437
# 33      1  4.736082  0.272880  0.626463  0.407587  0.111146
# 34      1  4.982048 -0.536095 -2.501374 -0.010875  0.906916
# 35      1  5.048963  1.856912 -1.344291  0.766477  0.494159)
# ................................................................................
# ('test y:', 0    -2.012788
# 1    -2.060723
# 2    -1.859440
# 3    -1.636049
# 4    -1.368214
# 5    -1.132723
# 6    -0.969602
# 7    -0.767620
# 8    -0.600077
# 9    -0.431603
# 10   -0.362957
# 11   -0.471860
# 12   -0.560053
# 13   -0.525381
# 14   -0.300362
# 15    0.013083
# 16    0.329087
# 17    0.620658
# 18    0.938058
# 19    1.175876
# 20    1.482572
# 21    1.711314
# 22    1.722716
# 23    0.889890
# 24    0.496630
# 25    0.354451
# 26    0.338628
# 27    0.414720
# 28    0.497560
# 29    0.451021
# 30    0.601809
# 31    0.776798
# 32    0.909436
# 33    0.701171
# 34    0.497328
# 35    0.136646
# Name: accident/day, dtype: float64)
# ================================================================================
# ('test X:\n', Empty DataFrame
# Columns: [const, x1, x2, x3, x4, x5]
# Index: [])
# ................................................................................
# ('test y:', Series([], Name: accident/day, dtype: float64))
# ================================================================================
# ('test X:\n', Empty DataFrame
# Columns: [const, x1, x2, x3, x4, x5]
# Index: [])
# ................................................................................
# ('test y:', Series([], Name: accident/day, dtype: float64))
# ================================================================================
# ('test X:\n', Empty DataFrame
# Columns: [const, x1, x2, x3, x4, x5]
# Index: [])
# ................................................................................
# ('test y:', Series([], Name: accident/day, dtype: float64))
# ================================================================================
# ('test X:\n', Empty DataFrame
# Columns: [const, x1, x2, x3, x4, x5]
# Index: [])
# ................................................................................
# ('test y:', Series([], Name: accident/day, dtype: float64))
# ================================================================================

# %%
print(len(cv))
# Out:
# 5

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

model = LinearRegression()

scores = np.zeros(5)

for i, (train_index, test_index) in enumerate(cv):
    X_train = df_cons.ix[train_index]
    y_train = df_y['accident/day'][train_index]
    X_test = df_cons.ix[test_index]
    y_test = df_y['accident/day'][test_index]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    #scores[i] = mean_squared_error(y_test, y_pred)
    scores[i] = r2_score(y_test, y_pred)

#np.mean(scores)
np.mean(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-58e783e39db0> in <module>()
#      12     X_test = df_cons.ix[test_index].T
#      13     y_test = df_y['accident/day'][test_index].T
# ---> 14     model.fit(X_train, y_train)
#      15     y_pred = model.predict(X_test)
#      16     #scores[i] = mean_squared_error(y_test, y_pred)
#
# c:\python27\lib\site-packages\sklearn\linear_model\base.pyc in fit(self, X, y, sample_weight)
#     425         to false, no intercept will be used in calculations
#     426         (e.g. data is expected to be already centered).
# --> 427
#     428     normalize : boolean, optional, default False
#     429         If True, the regressors X will be normalized before regression.
#
# c:\python27\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     508     estimator : str or estimator instance (default=None)
#     509         If passed, include the name of the estimator in warning messages.
# --> 510
#     511     Returns
#     512     -------
#
# c:\python27\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     413             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     414                              " minimum of %d is required%s."
# --> 415                              % (n_samples, shape_repr, ensure_min_samples,
#     416                                 context))
#     417
#
# ValueError: Found array with 0 feature(s) (shape=(6, 0)) while a minimum of 1 is required.
