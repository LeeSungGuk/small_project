# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale

# %%
df1 = pd.read_excel('./resource/teamproject_data.xlsx')

df2 = pd.DataFrame(data = df1, columns = ['accident'])

df2 

#df3 = scale(df2)
# Out:
#     accident
# 0       3038
# 1       2573
# 2       3126
# 3       3450
# 4       3603
# 5       3390
# 6       3529
# 7       3360
# 8       3433
# 9       3734
# 10      3701
# 11      3514
# 12      2990
# 13      3069
# 14      3356
# 15      3451
# 16      3605
# 17      3555
# 18      3581
# 19      3405
# 20      3480
# 21      3456
# 22      3621
# 23      3260
# 24      3005
# 25      2562
# 26      3311
# 27      3361
# 28      3643
# 29      3540
# 30      3304
# 31      3274
# 32      3265
# 33      3586
# 34      3472
# 35      3116
# 36      2687
# 37      2566
# 38      3335
# 39      3316
# 40      3628
# 41      3576
# 42      3752
# 43      3544
# 44      3482
# 45      3698
# 46      3656
# 47      3552
# 48      2967
# 49      2682
# 50      3384
# 51      3506
# 52      3669
# 53      3390
# 54      3647
# 55      3567
# 56      3711
# 57      3820
# 58      3794
# 59      3528

# %%
sns.pairplot(df3, vars=['accident', 'taxi_driver'])
plt.show()
